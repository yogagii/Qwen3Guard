# %% [markdown]
# # Hybrid Analyzer Evaluation
#
# 这个版本把中文主分析器抽象成可切换后端。你可以在同一套流程里选择 `hanlp + spacy` 或 `gliner + spacy`。

# %%
# %reload_ext autoreload
# %autoreload 2

from pprint import pprint

from presidio_evaluator.evaluation import ModelError

from mix_pipeline import HybridAnalyzerConfig, HybridAnalyzerExperiment
# Out:
# /home/capcom/anaconda3/envs/presidio-research/lib/python3.10/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/capcom/anaconda3/envs/presidio-research/lib/python3.10/site-packages/torch/cuda/__init__.py:435: UserWarning:
#     Found GPU0 NVIDIA GeForce GTX 1060 6GB which is of cuda capability 6.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   queued_call()
# /home/capcom/anaconda3/envs/presidio-research/lib/python3.10/site-packages/torch/cuda/__init__.py:435: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   queued_call()
# ...

# %%
# config = HybridAnalyzerConfig(
#     dataset_name="mixed_cn_en_3.json",
#     primary_backend="hanlp",  # 可切换为 "gliner"
#     primary_language="zh",
#     secondary_backend="spacy",
#     secondary_language="en",
#     evaluation_language="zh",
#     token_model_version="zh_core_web_sm",
#     labeling_scheme="IO",
#     iou_threshold=0.7,
#     extra_entity_mappings={"GENDER": "GENDER"},
#     # gliner_model_name="urchade/gliner_multi-v2.1",
#     # gliner_threshold=0.5,
# )

config = HybridAnalyzerConfig(
    dataset_name="mixed_cn_en_500.json",
    primary_backend="gliner",  # 可切换为 "gliner"
    primary_language="zh",
    secondary_backend="spacy",
    secondary_language="en",
    evaluation_language="zh",
    token_model_version="zh_core_web_sm",
    labeling_scheme="IO",
    iou_threshold=0.7,
    extra_entity_mappings={"GENDER": "GENDER"},
    gliner_model_name="/home/capcom/models/gliner-multi-edu",
    gliner_threshold=0.5,
)

pprint(config)
# Out:
# HybridAnalyzerConfig(project_dir=PosixPath('/home/capcom/presidio/Qwen3Guard'),
#                      data_dir=PosixPath('/home/capcom/presidio/Qwen3Guard/data'),
#                      dataset_name='mixed_cn_en_500.json',
#                      token_model_version='zh_core_web_sm',
#                      cuda_visible_devices='',
#                      primary_backend='gliner',
#                      primary_language='zh',
#                      secondary_backend='spacy',
#                      secondary_language='en',
#                      evaluation_language='zh',
#                      zh_tokenizer_model='COARSE_ELECTRA_SMALL_ZH',
#                      zh_ner_model='MSRA_NER_ELECTRA_SMALL_ZH',
#                      en_spacy_model='en_core_web_sm',
#                      gliner_model_name='/home/capcom/models/gliner-multi-edu',
#                      gliner_threshold=0.5,
#                      gliner_labels=['person name',
#                                     'location',
# ...

# %%
experiment = HybridAnalyzerExperiment(config)
dataset = experiment.load_dataset()
summary = experiment.summarize_dataset()
# Out:
# tokenizing input: 100%|██████████| 500/500 [00:04<00:00, 103.71it/s]
# 500
# Count per entity:
# [('O', 31462), ('STREET_ADDRESS', 2635), ('PERSON', 1563),
#  ('EMAIL_ADDRESS', 1190), ('AGE', 525), ('PHONE_NUMBER', 415), ('ID', 334),
#  ('GENDER', 320), ('GPE', 149), ('ORGANIZATION', 111), ('DATE_TIME', 82),
#  ('CREDIT_CARD', 45), ('DOMAIN_NAME', 43), ('TITLE', 43), ('IP_ADDRESS', 34),
#  ('IBAN_CODE', 16), ('ZIP_CODE', 15), ('US_SSN', 15), ('NRP', 13)]
#
# Min and max number of tokens in dataset: Min: 3, Max: 174
# Min and max sentence length in dataset: Min: 9, Max: 626

# %%
sample = experiment.inspect_sample(sample_index=0)
# Out:
# 000	莫雅琴	PERSON
# 001	是	O
# 002	一	O
# 003	位	O
# 004	36	AGE
# 005	岁	AGE
# 006	的	O
# 007	女性	GENDER
# 008	交响	O
# 009	乐团	O
# 010	指挥	O
# 011	。	O
# 012	她	O
# 013	居住	O
# 014	在	O
# 015	浙江省	STREET_ADDRESS
# 016	杭州市	STREET_ADDRESS
# 017	西湖区	STREET_ADDRESS
# 018	文三路	STREET_ADDRESS
# 019	218号	STREET_ADDRESS
# 020	，	O
# 021	持有	O
# 022	身份	O
# 023	证号	O
# 024	330106198701211528	ID
# 025	。	O
# 026	她	O
# 027	的	O
# 028	电子	O
# 029	邮箱	O
# 030	是	O
# 031	moyaq	EMAIL_ADDRESS
# 032	in	EMAIL_ADDRESS
# 033	@	EMAIL_ADDRESS
# 034	163.com	EMAIL_ADDRESS
# 035	，	O
# 036	联系	O
# 037	电话	O
# 038	为	O
# 039	13857192468	PHONE_NUMBER
# 040	。	O
# 041	莫雅琴	PERSON
# 042	近期	O
# 043	出现	O
# 044	关节	O
# 045	疼痛	O
# 046	、	O
# 047	僵硬	O
# 048	和	O
# 049	活动	O
# 050	受限	O
# 051	的	O
# 052	症状	O
# 053	，	O
# 054	经	O
# 055	诊断	O
# 056	为	O
# 057	关节炎	O
# 058	。	O
# 059	她	O
# 060	的	O
# 061	主治	O
# 062	医生	O
# 063	张明远	PERSON
# 064	为	O
# 065	其	O
# 066	开具	O
# 067	了	O
# 068	阿司匹林	O
# 069	进行	O
# 070	治疗	O
# 071	。	O
# 072	财务	O
# 073	状况	O
# 074	方面	O
# 075	，	O
# ...

# %%
primary_analyzer, secondary_analyzer = experiment.build_analyzers()
dataset = experiment.align_dataset_entities()
experiment.describe_analyzers()
# Out:
# loading config  /home/capcom/models/gliner-multi-edu {'person': 'PERSON', 'location': 'LOCATION', 'age': 'AGE', 'email address': 'EMAIL_ADDRESS', 'phone number': 'PHONE_NUMBER', 'credit_card': 'CREDIT_CARD', 'gender': 'gender'} ['person name', 'location', 'organization', 'phone number', 'email address', 'id number', 'age', 'url']
# loading recognizer
# end recognizer
# Loading GLiNER model from /home/capcom/models/gliner-multi-edu on CPU...
# /home/capcom/anaconda3/envs/presidio-research/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:566: UserWarning:
#
# The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.

# %%
cn_text = "陶立轩是一位62岁的男性软件开发工程师。他居住在浙江省杭州市西湖区文三路826号。"

anonymized_text = experiment.anonymize_text(cn_text)
print(anonymized_text)
# Out:
# Running GLiNER inference...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# GLiNER inference finished in 0.3s
# text: 陶立轩是一位<AGE>岁的<GENDER>软件开发工程师。他居住在浙江省杭州市西湖区文三路826号。
# items:
# [
#     {'start': 13, 'end': 21, 'entity_type': 'GENDER', 'text': '<GENDER>', 'operator': 'replace'},
#     {'start': 6, 'end': 11, 'entity_type': 'AGE', 'text': '<AGE>', 'operator': 'replace'}
# ]

# %%
debug_info = experiment.debug_sample(sample_index=0)
experiment.print_results(debug_info["combined_results"], debug_info["text"])

# 也可以直接调试任意输入文本
# cn_text = "陶立轩是一位62岁的男性软件开发工程师。他居住在浙江省杭州市西湖区文三路826号。"
# debug_text_info = experiment.debug_text(cn_text)
# debug_text_info["anonymized_text"]
# Out:
# Running GLiNER inference...
# GLiNER inference finished in 0.8s
# 莫雅琴是一位36岁的女性交响乐团指挥。她居住在浙江省杭州市西湖区文三路218号，持有身份证号330106198701211528。她的电子邮箱是moyaqin@163.com，联系电话为13857192468。莫雅琴近期出现关节疼痛、僵硬和活动受限的症状，经诊断为关节炎。她的主治医生张明远为其开具了阿司匹林进行治疗。财务状况方面，她的信用评分为850分，年收入为921736.42元。交易记录显示有一笔'收入转账 REMI17121'的款项。
#
# gliner_results:
# [type: PHONE_NUMBER, start: 93, end: 104, score: 0.9892788529396057, type: ID, start: 46, end: 64, score: 0.95, type: EMAIL_ADDRESS, start: 72, end: 87, score: 0.85, type: GENDER, start: 10, end: 12, score: 0.8, type: AGE, start: 6, end: 9, score: 0.5863768458366394]
#
# spacy_results:
# [type: EMAIL_ADDRESS, start: 65, end: 87, score: 1.0, type: URL, start: 80, end: 87, score: 0.5, type: PHONE_NUMBER, start: 93, end: 104, score: 0.4]
#
# combined_results:
# ...

# %%
artifacts = experiment.run_evaluation()
results = artifacts.results
evaluation_results = artifacts.evaluation_results
results
# Out:
# Running model HybridAnalyzerModelWrapper on dataset...
# Running GLiNER inference...
# /home/capcom/presidio/presidio-research/presidio_evaluator/evaluation/base_evaluator.py:83: UserWarning: skip words not provided, using default skip words. If you want the evaluation to not use skip words, pass skip_words=[]
#   warnings.warn("skip words not provided, using default skip words. "
# GLiNER inference finished in 0.8s
# Running GLiNER inference...
# GLiNER inference finished in 0.2s
# Running GLiNER inference...
# GLiNER inference finished in 0.8s
# Finished running model on dataset
# saving experiment data to /home/capcom/presidio/Qwen3Guard/experiment_20260323-183142.json
# stats=Counter({('PERSON', 'O'): 5, ('GENDER', 'GENDER'): 2, ('LOCATION', 'O'): 2, ('ID', 'ID'): 2, ('PHONE_NUMBER', 'PHONE_NUMBER'): 2, ('AGE', 'AGE'): 1, ('EMAIL_ADDRESS', 'O'): 1, ('O', 'EMAIL_ADDRESS'): 1, ('CREDIT_CARD', 'DATE_TIME'): 1, ('AGE', 'O'): 1, ('EMAIL_ADDRESS', 'EMAIL_ADDRESS'): 1})

# %%
predicted_label_counts = experiment.get_predicted_label_counts(evaluation_results)
predicted_label_counts
# Out:
# Counter({'EMAIL_ADDRESS': 13,
#          'AGE': 2,
#          'GENDER': 2,
#          'ID': 2,
#          'PHONE_NUMBER': 2,
#          'DATE_TIME': 1})

# %%
output_folder = experiment.plot_results(results)
output_folder
# Out:
# PosixPath('/home/capcom/presidio/Qwen3Guard/plotter_output')

# %%
ModelError.most_common_fp_tokens(results.model_errors)

# %%
fps_df = ModelError.get_fps_dataframe(results.model_errors)
fps_df[["full_text", "token", "annotation", "prediction"]].head(20)

# %%
ModelError.most_common_fn_tokens(results.model_errors, n=15)

# %%
fns_df = ModelError.get_fns_dataframe(results.model_errors)
fns_df[["full_text", "token", "annotation", "prediction"]].head(20)
